# %%
# Jupyter notebook for GPT pretraining.

import os

from datasets.text_dataset import TextDataset
from tokenizers.char_tokenizer import CharTokenizer
from layers.gpt import GPT
from layers import layer_utils
from evaluate import Evaluator

from collections.abc import Callable
import torch, torch.nn as nn


# Define hyperparameters.

# Dataset hyper parameters
data_filename = 'testdata/tinyshakespeare.txt'
train_fraction = 0.9

# Tokenizer hyperparameters.
tokenizer = CharTokenizer(filename = data_filename)

# Architecture hyperparameters.
embedding_dimension = 64
num_heads = 8
head_dimension = 16
num_decoder_blocks = 10

# Training hyperparameters.
max_block_size = 24
batch_size = 32
num_batches_to_train = 500

# Evaluation hyperparameters.
num_batches_to_evaluate = 10
num_tokens_to_generate_during_evaluation = 10
num_batches_between_evaluations = 10

# Output parameters.
output_model_path = 'output/gpt.pt'
output_params_path = 'output/num_parameters.yaml'

# Fixing seed for reproducing results.
torch.manual_seed(123)

# Create directory corresponding to output_model_path if it does not exist.
model_dirname = os.path.dirname(output_model_path)
if not os.path.exists(model_dirname):
    os.makedirs(model_dirname)

# Generate train and validation datasets and data loaders.
train_dataset = TextDataset(max_block_size, tokenizer, 'train', train_fraction, filename = data_filename)
val_dataset = TextDataset(max_block_size, tokenizer, 'val', train_fraction, filename = data_filename)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle = True)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size, shuffle = True)

# Define the model architecture and optimizer.
model = GPT(num_decoder_blocks, tokenizer.vocabulary_length(), embedding_dimension, num_heads, head_dimension, max_block_size)
num_model_parameters = layer_utils.num_parameters(model, output_params_path)
print(f'Number of parameters in the model is {num_model_parameters["total_trainable_parameters"]}.')

optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
evaluator = Evaluator()

# Perform model training and evaluation.
for (batch_index, train_batch) in enumerate(train_dataloader):
    if batch_index > num_batches_to_train:
        print('Reached maximum number of matches. Training is now complete.')
        torch.save(model.state_dict(), output_model_path)
        break

    train_features = train_batch['features']
    train_labels = train_batch['labels']
    predictions, loss = model(train_features, train_labels)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if batch_index % num_batches_between_evaluations == 0:
        (train_loss, val_loss) = evaluator.evaluate_train_and_validation_loss(train_dataloader, val_dataloader, model, num_batches_to_evaluate)
        generated_text = evaluator.generate_text(model, num_tokens_to_generate_during_evaluation, tokenizer)
        print(f' Batch index: {batch_index}, train loss: {train_loss}, val_loss: {val_loss}, generated text\n {generated_text}')
# Out:
# Number of parameters in the model is 509121.
#  Batch index: 0, train loss: 4.119297027587891, val_loss: 4.1172614097595215, generated text
#
# ,:zisiOUOM
#  Batch index: 10, train loss: 4.018176078796387, val_loss: 4.020906448364258, generated text
#
# bHfi.eOQFx
#  Batch index: 20, train loss: 3.9223999977111816, val_loss: 3.928990125656128, generated text
#
#
# VakbdQh'l
#  Batch index: 30, train loss: 3.8112730979919434, val_loss: 3.833385944366455, generated text
#
# hu: pJXZBu
#  Batch index: 40, train loss: 3.703054428100586, val_loss: 3.7184596061706543, generated text
#
# &lwDnuIm.x
#  Batch index: 50, train loss: 3.5785396099090576, val_loss: 3.5882728099823, generated text
#
#  yeaHoi
# O3
#  Batch index: 60, train loss: 3.4777920246124268, val_loss: 3.496640682220459, generated text
#
# ynEk sbaUa
#  Batch index: 70, train loss: 3.3958580493927, val_loss: 3.4972081184387207, generated text
#
#  VhenoI,
# f
#  Batch index: 80, train loss: 3.368961811065674, val_loss: 3.406102418899536, generated text
#
#  $br  i&Lk
#  Batch index: 90, train loss: 3.333815097808838, val_loss: 3.3738174438476562, generated text
#
# en3ii tho
#  Batch index: 100, train loss: 3.266991376876831, val_loss: 3.335987091064453, generated text
#
# ld ' h see
#  Batch index: 110, train loss: 3.2639992237091064, val_loss: 3.299140214920044, generated text
#
#  ritlerhoo
#  Batch index: 120, train loss: 3.2141318321228027, val_loss: 3.264146327972412, generated text
#
# eog  u ai
#  Batch index: 130, train loss: 3.240203380584717, val_loss: 3.2464804649353027, generated text
#
# st,e cil F
#  Batch index: 140, train loss: 3.173405170440674, val_loss: 3.2465033531188965, generated text
#
# aaeto heyn
#  Batch index: 150, train loss: 3.1555373668670654, val_loss: 3.1801066398620605, generated text
#
# trephoyeir
#  Batch index: 160, train loss: 3.1214568614959717, val_loss: 3.185434341430664, generated text
#
# i ey 3ghha
#  Batch index: 170, train loss: 3.1105730533599854, val_loss: 3.152801275253296, generated text
#
#
# goaahoaE
#  Batch index: 180, train loss: 3.138172149658203, val_loss: 3.1614999771118164, generated text
#
# W rheyllh
#  Batch index: 190, train loss: 3.1014013290405273, val_loss: 3.167498826980591, generated text
#
# d debf'iwt
#  Batch index: 200, train loss: 3.089521884918213, val_loss: 3.1329448223114014, generated text
#
#  weid t f
#  Batch index: 210, train loss: 3.061448097229004, val_loss: 3.1484627723693848, generated text
#
# lr hy ureh
#  Batch index: 220, train loss: 3.0546677112579346, val_loss: 3.1322925090789795, generated text
#
# tuhe g us;
#  Batch index: 230, train loss: 3.060108184814453, val_loss: 3.1223363876342773, generated text
#
# dTmitlcnn,
#  Batch index: 240, train loss: 3.0069918632507324, val_loss: 3.1721627712249756, generated text
#
#  E u t t a
#  Batch index: 250, train loss: 3.0237488746643066, val_loss: 3.126075029373169, generated text
#
# gI
# hd  ad
#
#  Batch index: 260, train loss: 3.012957811355591, val_loss: 3.1079587936401367, generated text
#
# ,id
# di sit
#  Batch index: 270, train loss: 2.9915661811828613, val_loss: 3.1204326152801514, generated text
#
# eoi Ied wa
#  Batch index: 280, train loss: 3.0208640098571777, val_loss: 3.1111063957214355, generated text
#
# m:ahtwey;
#  Batch index: 290, train loss: 3.013035297393799, val_loss: 3.0488224029541016, generated text
#
#
# nesN t
# m
#  Batch index: 300, train loss: 3.0168662071228027, val_loss: 3.0443332195281982, generated text
#
# ?aI wa s E
#  Batch index: 310, train loss: 2.9774489402770996, val_loss: 3.040832996368408, generated text
#
# aeeuhao u
#  Batch index: 320, train loss: 2.9804370403289795, val_loss: 3.0276312828063965, generated text
#
# esoase,ang
#  Batch index: 330, train loss: 2.93206787109375, val_loss: 3.032538652420044, generated text
#
#  aly naIg.
#  Batch index: 340, train loss: 2.9666075706481934, val_loss: 3.0337166786193848, generated text
#
# ue,'E'etow
#  Batch index: 350, train loss: 2.9399287700653076, val_loss: 2.9849674701690674, generated text
#
# lh cu, wos
#  Batch index: 360, train loss: 2.9660401344299316, val_loss: 3.015225887298584, generated text
#
# su ld
# N u
#  Batch index: 370, train loss: 2.9467339515686035, val_loss: 2.9591403007507324, generated text
#
# ao,odcoOOa
#  Batch index: 380, train loss: 2.937966823577881, val_loss: 2.9560790061950684, generated text
#
# a gedey: m
#  Batch index: 390, train loss: 2.8964433670043945, val_loss: 2.9368607997894287, generated text
#
# eyoai deu
#  Batch index: 400, train loss: 2.937608003616333, val_loss: 3.026188373565674, generated text
#
# hehhshed b
#  Batch index: 410, train loss: 2.9323830604553223, val_loss: 2.9831223487854004, generated text
#
# fto wau f,
#  Batch index: 420, train loss: 2.927051067352295, val_loss: 2.9058456420898438, generated text
#
# i c , taQ
#
#  Batch index: 430, train loss: 2.933353900909424, val_loss: 2.9671623706817627, generated text
#
# i
# he antoy
#  Batch index: 440, train loss: 2.9013378620147705, val_loss: 2.9345078468322754, generated text
#
# uo syheoll
#  Batch index: 450, train loss: 2.927574634552002, val_loss: 2.906203269958496, generated text
#
#  oIEote se
#  Batch index: 460, train loss: 2.898416042327881, val_loss: 2.924403429031372, generated text
#
# s v rh-nns
#  Batch index: 470, train loss: 2.8324320316314697, val_loss: 2.9113354682922363, generated text
#
# eeoocanei
#  Batch index: 480, train loss: 2.9127273559570312, val_loss: 2.878974437713623, generated text
#
# a ee lega?
#  Batch index: 490, train loss: 2.9013218879699707, val_loss: 2.941518545150757, generated text
#
# c nhTefoni
#  Batch index: 500, train loss: 2.9048027992248535, val_loss: 2.882061719894409, generated text
#
# a   ua sea
# Reached maximum number of matches. Training is now complete.

# %%
model_path = 'gpt.pt'
model = GPT(num_decoder_blocks, tokenizer.vocabulary_length(), embedding_dimension, num_heads, head_dimension, max_block_size)

model.load_state_dict(torch.load(model_path))

for (name, module) in model.named_modules():
    print(name, module)
# Out:
#  GPT(
#   (token_embedding_layer): Embedding(65, 64)
#   (positional_encoding_layer): Embedding(24, 64)
#   (transformer_decoders): ModuleList(
#     (0-9): 10 x TransformerDecoderBlock(
#       (attention_layer): MultiHeadMaskedAttention(
#         (Wq): Linear(in_features=64, out_features=128, bias=True)
#         (Wk): Linear(in_features=64, out_features=128, bias=True)
#         (Wv): Linear(in_features=64, out_features=128, bias=True)
#         (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#       )
#       (mlp_layer): MLP(
#         (layer): Sequential(
#           (0): Linear(in_features=64, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=64, bias=True)
#         )
#       )
#       (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (head_layer): Linear(in_features=64, out_features=65, bias=True)
# )
# token_embedding_layer Embedding(65, 64)
# positional_encoding_layer Embedding(24, 64)
# transformer_decoders ModuleList(
#   (0-9): 10 x TransformerDecoderBlock(
#     (attention_layer): MultiHeadMaskedAttention(
#       (Wq): Linear(in_features=64, out_features=128, bias=True)
#       (Wk): Linear(in_features=64, out_features=128, bias=True)
#       (Wv): Linear(in_features=64, out_features=128, bias=True)
#       (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#     )
#     (mlp_layer): MLP(
#       (layer): Sequential(
#         (0): Linear(in_features=64, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=64, bias=True)
#       )
#     )
#     (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
# )
# transformer_decoders.0 TransformerDecoderBlock(
#   (attention_layer): MultiHeadMaskedAttention(
#     (Wq): Linear(in_features=64, out_features=128, bias=True)
#     (Wk): Linear(in_features=64, out_features=128, bias=True)
#     (Wv): Linear(in_features=64, out_features=128, bias=True)
#     (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (mlp_layer): MLP(
#     (layer): Sequential(
#       (0): Linear(in_features=64, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=64, bias=True)
#     )
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# )
# transformer_decoders.0.attention_layer MultiHeadMaskedAttention(
#   (Wq): Linear(in_features=64, out_features=128, bias=True)
#   (Wk): Linear(in_features=64, out_features=128, bias=True)
#   (Wv): Linear(in_features=64, out_features=128, bias=True)
#   (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.0.attention_layer.Wq Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.0.attention_layer.Wk Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.0.attention_layer.Wv Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.0.attention_layer.head_merge_layer Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.0.mlp_layer MLP(
#   (layer): Sequential(
#     (0): Linear(in_features=64, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#   )
# )
# transformer_decoders.0.mlp_layer.layer Sequential(
#   (0): Linear(in_features=64, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.0.mlp_layer.layer.0 Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.0.mlp_layer.layer.1 ReLU()
# transformer_decoders.0.mlp_layer.layer.2 Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.0.layer_norm LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# transformer_decoders.1 TransformerDecoderBlock(
#   (attention_layer): MultiHeadMaskedAttention(
#     (Wq): Linear(in_features=64, out_features=128, bias=True)
#     (Wk): Linear(in_features=64, out_features=128, bias=True)
#     (Wv): Linear(in_features=64, out_features=128, bias=True)
#     (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (mlp_layer): MLP(
#     (layer): Sequential(
#       (0): Linear(in_features=64, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=64, bias=True)
#     )
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# )
# transformer_decoders.1.attention_layer MultiHeadMaskedAttention(
#   (Wq): Linear(in_features=64, out_features=128, bias=True)
#   (Wk): Linear(in_features=64, out_features=128, bias=True)
#   (Wv): Linear(in_features=64, out_features=128, bias=True)
#   (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.1.attention_layer.Wq Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.1.attention_layer.Wk Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.1.attention_layer.Wv Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.1.attention_layer.head_merge_layer Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.1.mlp_layer MLP(
#   (layer): Sequential(
#     (0): Linear(in_features=64, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#   )
# )
# transformer_decoders.1.mlp_layer.layer Sequential(
#   (0): Linear(in_features=64, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.1.mlp_layer.layer.0 Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.1.mlp_layer.layer.1 ReLU()
# transformer_decoders.1.mlp_layer.layer.2 Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.1.layer_norm LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# transformer_decoders.2 TransformerDecoderBlock(
#   (attention_layer): MultiHeadMaskedAttention(
#     (Wq): Linear(in_features=64, out_features=128, bias=True)
#     (Wk): Linear(in_features=64, out_features=128, bias=True)
#     (Wv): Linear(in_features=64, out_features=128, bias=True)
#     (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (mlp_layer): MLP(
#     (layer): Sequential(
#       (0): Linear(in_features=64, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=64, bias=True)
#     )
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# )
# transformer_decoders.2.attention_layer MultiHeadMaskedAttention(
#   (Wq): Linear(in_features=64, out_features=128, bias=True)
#   (Wk): Linear(in_features=64, out_features=128, bias=True)
#   (Wv): Linear(in_features=64, out_features=128, bias=True)
#   (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.2.attention_layer.Wq Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.2.attention_layer.Wk Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.2.attention_layer.Wv Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.2.attention_layer.head_merge_layer Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.2.mlp_layer MLP(
#   (layer): Sequential(
#     (0): Linear(in_features=64, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#   )
# )
# transformer_decoders.2.mlp_layer.layer Sequential(
#   (0): Linear(in_features=64, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.2.mlp_layer.layer.0 Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.2.mlp_layer.layer.1 ReLU()
# transformer_decoders.2.mlp_layer.layer.2 Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.2.layer_norm LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# transformer_decoders.3 TransformerDecoderBlock(
#   (attention_layer): MultiHeadMaskedAttention(
#     (Wq): Linear(in_features=64, out_features=128, bias=True)
#     (Wk): Linear(in_features=64, out_features=128, bias=True)
#     (Wv): Linear(in_features=64, out_features=128, bias=True)
#     (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (mlp_layer): MLP(
#     (layer): Sequential(
#       (0): Linear(in_features=64, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=64, bias=True)
#     )
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# )
# transformer_decoders.3.attention_layer MultiHeadMaskedAttention(
#   (Wq): Linear(in_features=64, out_features=128, bias=True)
#   (Wk): Linear(in_features=64, out_features=128, bias=True)
#   (Wv): Linear(in_features=64, out_features=128, bias=True)
#   (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.3.attention_layer.Wq Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.3.attention_layer.Wk Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.3.attention_layer.Wv Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.3.attention_layer.head_merge_layer Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.3.mlp_layer MLP(
#   (layer): Sequential(
#     (0): Linear(in_features=64, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#   )
# )
# transformer_decoders.3.mlp_layer.layer Sequential(
#   (0): Linear(in_features=64, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.3.mlp_layer.layer.0 Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.3.mlp_layer.layer.1 ReLU()
# transformer_decoders.3.mlp_layer.layer.2 Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.3.layer_norm LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# transformer_decoders.4 TransformerDecoderBlock(
#   (attention_layer): MultiHeadMaskedAttention(
#     (Wq): Linear(in_features=64, out_features=128, bias=True)
#     (Wk): Linear(in_features=64, out_features=128, bias=True)
#     (Wv): Linear(in_features=64, out_features=128, bias=True)
#     (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (mlp_layer): MLP(
#     (layer): Sequential(
#       (0): Linear(in_features=64, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=64, bias=True)
#     )
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# )
# transformer_decoders.4.attention_layer MultiHeadMaskedAttention(
#   (Wq): Linear(in_features=64, out_features=128, bias=True)
#   (Wk): Linear(in_features=64, out_features=128, bias=True)
#   (Wv): Linear(in_features=64, out_features=128, bias=True)
#   (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.4.attention_layer.Wq Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.4.attention_layer.Wk Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.4.attention_layer.Wv Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.4.attention_layer.head_merge_layer Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.4.mlp_layer MLP(
#   (layer): Sequential(
#     (0): Linear(in_features=64, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#   )
# )
# transformer_decoders.4.mlp_layer.layer Sequential(
#   (0): Linear(in_features=64, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.4.mlp_layer.layer.0 Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.4.mlp_layer.layer.1 ReLU()
# transformer_decoders.4.mlp_layer.layer.2 Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.4.layer_norm LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# transformer_decoders.5 TransformerDecoderBlock(
#   (attention_layer): MultiHeadMaskedAttention(
#     (Wq): Linear(in_features=64, out_features=128, bias=True)
#     (Wk): Linear(in_features=64, out_features=128, bias=True)
#     (Wv): Linear(in_features=64, out_features=128, bias=True)
#     (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (mlp_layer): MLP(
#     (layer): Sequential(
#       (0): Linear(in_features=64, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=64, bias=True)
#     )
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# )
# transformer_decoders.5.attention_layer MultiHeadMaskedAttention(
#   (Wq): Linear(in_features=64, out_features=128, bias=True)
#   (Wk): Linear(in_features=64, out_features=128, bias=True)
#   (Wv): Linear(in_features=64, out_features=128, bias=True)
#   (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.5.attention_layer.Wq Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.5.attention_layer.Wk Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.5.attention_layer.Wv Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.5.attention_layer.head_merge_layer Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.5.mlp_layer MLP(
#   (layer): Sequential(
#     (0): Linear(in_features=64, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#   )
# )
# transformer_decoders.5.mlp_layer.layer Sequential(
#   (0): Linear(in_features=64, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.5.mlp_layer.layer.0 Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.5.mlp_layer.layer.1 ReLU()
# transformer_decoders.5.mlp_layer.layer.2 Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.5.layer_norm LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# transformer_decoders.6 TransformerDecoderBlock(
#   (attention_layer): MultiHeadMaskedAttention(
#     (Wq): Linear(in_features=64, out_features=128, bias=True)
#     (Wk): Linear(in_features=64, out_features=128, bias=True)
#     (Wv): Linear(in_features=64, out_features=128, bias=True)
#     (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (mlp_layer): MLP(
#     (layer): Sequential(
#       (0): Linear(in_features=64, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=64, bias=True)
#     )
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# )
# transformer_decoders.6.attention_layer MultiHeadMaskedAttention(
#   (Wq): Linear(in_features=64, out_features=128, bias=True)
#   (Wk): Linear(in_features=64, out_features=128, bias=True)
#   (Wv): Linear(in_features=64, out_features=128, bias=True)
#   (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.6.attention_layer.Wq Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.6.attention_layer.Wk Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.6.attention_layer.Wv Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.6.attention_layer.head_merge_layer Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.6.mlp_layer MLP(
#   (layer): Sequential(
#     (0): Linear(in_features=64, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#   )
# )
# transformer_decoders.6.mlp_layer.layer Sequential(
#   (0): Linear(in_features=64, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.6.mlp_layer.layer.0 Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.6.mlp_layer.layer.1 ReLU()
# transformer_decoders.6.mlp_layer.layer.2 Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.6.layer_norm LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# transformer_decoders.7 TransformerDecoderBlock(
#   (attention_layer): MultiHeadMaskedAttention(
#     (Wq): Linear(in_features=64, out_features=128, bias=True)
#     (Wk): Linear(in_features=64, out_features=128, bias=True)
#     (Wv): Linear(in_features=64, out_features=128, bias=True)
#     (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (mlp_layer): MLP(
#     (layer): Sequential(
#       (0): Linear(in_features=64, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=64, bias=True)
#     )
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# )
# transformer_decoders.7.attention_layer MultiHeadMaskedAttention(
#   (Wq): Linear(in_features=64, out_features=128, bias=True)
#   (Wk): Linear(in_features=64, out_features=128, bias=True)
#   (Wv): Linear(in_features=64, out_features=128, bias=True)
#   (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.7.attention_layer.Wq Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.7.attention_layer.Wk Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.7.attention_layer.Wv Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.7.attention_layer.head_merge_layer Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.7.mlp_layer MLP(
#   (layer): Sequential(
#     (0): Linear(in_features=64, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#   )
# )
# transformer_decoders.7.mlp_layer.layer Sequential(
#   (0): Linear(in_features=64, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.7.mlp_layer.layer.0 Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.7.mlp_layer.layer.1 ReLU()
# transformer_decoders.7.mlp_layer.layer.2 Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.7.layer_norm LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# transformer_decoders.8 TransformerDecoderBlock(
#   (attention_layer): MultiHeadMaskedAttention(
#     (Wq): Linear(in_features=64, out_features=128, bias=True)
#     (Wk): Linear(in_features=64, out_features=128, bias=True)
#     (Wv): Linear(in_features=64, out_features=128, bias=True)
#     (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (mlp_layer): MLP(
#     (layer): Sequential(
#       (0): Linear(in_features=64, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=64, bias=True)
#     )
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# )
# transformer_decoders.8.attention_layer MultiHeadMaskedAttention(
#   (Wq): Linear(in_features=64, out_features=128, bias=True)
#   (Wk): Linear(in_features=64, out_features=128, bias=True)
#   (Wv): Linear(in_features=64, out_features=128, bias=True)
#   (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.8.attention_layer.Wq Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.8.attention_layer.Wk Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.8.attention_layer.Wv Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.8.attention_layer.head_merge_layer Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.8.mlp_layer MLP(
#   (layer): Sequential(
#     (0): Linear(in_features=64, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#   )
# )
# transformer_decoders.8.mlp_layer.layer Sequential(
#   (0): Linear(in_features=64, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.8.mlp_layer.layer.0 Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.8.mlp_layer.layer.1 ReLU()
# transformer_decoders.8.mlp_layer.layer.2 Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.8.layer_norm LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# transformer_decoders.9 TransformerDecoderBlock(
#   (attention_layer): MultiHeadMaskedAttention(
#     (Wq): Linear(in_features=64, out_features=128, bias=True)
#     (Wk): Linear(in_features=64, out_features=128, bias=True)
#     (Wv): Linear(in_features=64, out_features=128, bias=True)
#     (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (mlp_layer): MLP(
#     (layer): Sequential(
#       (0): Linear(in_features=64, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=64, bias=True)
#     )
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# )
# transformer_decoders.9.attention_layer MultiHeadMaskedAttention(
#   (Wq): Linear(in_features=64, out_features=128, bias=True)
#   (Wk): Linear(in_features=64, out_features=128, bias=True)
#   (Wv): Linear(in_features=64, out_features=128, bias=True)
#   (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.9.attention_layer.Wq Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.9.attention_layer.Wk Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.9.attention_layer.Wv Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.9.attention_layer.head_merge_layer Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.9.mlp_layer MLP(
#   (layer): Sequential(
#     (0): Linear(in_features=64, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#   )
# )
# transformer_decoders.9.mlp_layer.layer Sequential(
#   (0): Linear(in_features=64, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
# )
# transformer_decoders.9.mlp_layer.layer.0 Linear(in_features=64, out_features=128, bias=True)
# transformer_decoders.9.mlp_layer.layer.1 ReLU()
# transformer_decoders.9.mlp_layer.layer.2 Linear(in_features=128, out_features=64, bias=True)
# transformer_decoders.9.layer_norm LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# head_layer Linear(in_features=64, out_features=65, bias=True)

# %%
model
# Out:
# GPT(
#   (token_embedding_layer): Embedding(65, 64)
#   (positional_encoding_layer): Embedding(24, 64)
#   (transformer_decoders): ModuleList(
#     (0-9): 10 x TransformerDecoderBlock(
#       (attention_layer): MultiHeadMaskedAttention(
#         (Wq): Linear(in_features=64, out_features=128, bias=True)
#         (Wk): Linear(in_features=64, out_features=128, bias=True)
#         (Wv): Linear(in_features=64, out_features=128, bias=True)
#         (head_merge_layer): Linear(in_features=128, out_features=64, bias=True)
#       )
#       (mlp_layer): MLP(
#         (layer): Sequential(
#           (0): Linear(in_features=64, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=64, bias=True)
#         )
#       )
#       (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (head_layer): Linear(in_features=64, out_features=65, bias=True)
# )

# %%
model.named_modules()
# Out:
# <generator object Module.named_modules at 0x7fcf4b85e6d0>

# %%
model.state_dict()
# Out:
# OrderedDict([('token_embedding_layer.weight',
#               tensor([[ 0.3120, -0.1683, -0.3132,  ..., -0.8087,  0.1813,  0.2064],
#                       [ 0.5178,  0.9949, -0.2497,  ...,  1.2679, -1.4586, -2.1651],
#                       [-0.2390, -2.0628, -0.8271,  ...,  0.1260,  0.8500,  0.0474],
#                       ...,
#                       [-0.7930,  0.5108, -1.7304,  ...,  0.4013,  2.5323, -1.2270],
#                       [ 0.3892,  0.0225, -0.6838,  ...,  0.2072, -0.0805, -0.7841],
#                       [-1.2294, -0.6343, -0.1646,  ...,  0.1857, -0.7578,  0.5398]])),
#              ('positional_encoding_layer.weight',
#               tensor([[-1.0398, -0.6559,  0.9377,  ...,  0.1232, -1.2365, -0.1056],
#                       [ 0.2216,  0.5529, -1.5980,  ..., -0.9717, -1.7982, -1.8113],
#                       [-0.6465,  0.7719, -0.7789,  ..., -0.2921, -0.5079, -0.0046],
#                       ...,
#                       [-0.5420,  1.5233,  0.8172,  ...,  0.8380, -0.0911,  1.0546],
#                       [ 0.7844, -0.9118, -1.1794,  ..., -0.9801, -0.4520, -0.3411],
#                       [ 0.9008,  1.3286,  1.9293,  ..., -0.5472,  0.7769,  0.2402]])),
#              ('transformer_decoders.0.attention_layer.Wq.weight',
#               tensor([[ 0.1080,  0.0479,  0.0218,  ..., -0.1143,  0.0405,  0.0641],
#                       [-0.0403,  0.0186,  0.0146,  ...,  0.0971, -0.0598,  0.0636],
#                       [-0.0899, -0.0701,  0.0618,  ...,  0.0758,  0.0602, -0.0244],
#                       ...,
#                       [-0.0675, -0.0971,  0.0513,  ...,  0.0038, -0.0247,  0.0710],
#                       [-0.0380,  0.0019,  0.0176,  ...,  0.0491,  0.0240,  0.0173],
#                       [ 0.0451, -0.0525,  0.0618,  ...,  0.1082,  0.0729, -0.1068]])),
#              ('transformer_decoders.0.attention_layer.Wq.bias',
#               tensor([-0.0963, -0.1038,  0.0085, -0.1208,  0.1245, -0.0785, -0.0336,  0.0093,
#                       -0.0790,  0.1173, -0.0486,  0.1204, -0.1238, -0.0391, -0.0594, -0.0387,
#                        0.0385,  0.0227, -0.0776, -0.0533,  0.0699,  0.0269,  0.1018, -0.1080,
#                       -0.0400, -0.0323, -0.0825, -0.0854, -0.0236, -0.0304,  0.1037, -0.1209,
#                        0.0430,  0.0394,  0.0932,  0.0343,  0.0132,  0.1122,  0.0164, -0.1246,
#                       -1.0025e-01,  8.5007e-02,  1.2186e-01])),
#              ('transformer_decoders.1.attention_layer.head_merge_layer.weight',
#               tensor([[-0.0544,  0.0853,  0.0443,  ...,  0.0230,  0.0081,  0.0607],
#                       [ 0.0712, -0.0892, -0.0118,  ...,  0.0234,  0.0458, -0.0676],
#                       [-0.0004, -0.0302, -0.0643,  ..., -0.0403, -0.0223,  0.0291],
#                       ...,
#                       [-0.0132,  0.0693,  0.0593,  ..., -0.0481, -0.0270, -0.0333],
#                       [ 0.0829,  0.0733, -0.0076,  ..., -0.0637,  0.0451,  0.0181],
#                       [-0.0151,  0.0795, -0.0501,  ..., -0.0097, -0.0704,  0.0119]])),
#              ('transformer_decoders.1.attention_layer.head_merge_layer.bias',
#               tensor([ 0.0030,  0.0512, -0.0441,  0.0550, -0.0259,  0.0608,  0.0746, -0.0017,
#                       -0.0546, -0.0773,  0.0509, -0.0094, -0.0191,  0.0816,  0.0329, -0.0652,
#                       -0.0773, -0.0713,  0.0596, -0.0097, -0.0206, -0.0241, -0.0845, -0.0409,
#                        0.0778,  0.0641,  0.0323, -0.0528, -0.0016, -0.0420,  0.0375,  0.0122,
#                        0.0430,  0.0455,  0.0073, -0.0108, -0.0528,  0.0357, -0.0781, -0.0799,
#                        0.0403, -0.0695, -0.0198, -0.0721, -0.0064,  0.0091, -0.0106, -0.0487,
#                        0.0432,  0.0280,  0.0704,  0.0196,  0.0296, -0.0732,  0.0084, -0.0306,
#                        0.0162, -0.0688,  0.0447,  0.0589, -0.0104,  0.0363,  0.0381,  0.0401])),
#              ('transformer_decoders.1.mlp_layer.layer.0.weight',
#               tensor([[-0.0563, -0.1183, -0.0261,  ...,  0.0344, -0.0854, -0.0153],
#                       [-0.0672,  0.0164, -0.1188,  ...,  0.0798, -0.0025,  0.0101],
#                       [ 0.0761, -0.0392,  0.0144,  ...,  0.0341,  0.0216, -0.0561],
#                       ...,
#                       [-0.1118,  0.0303, -0.0737,  ..., -0.0969, -0.0825,  0.0369],
#                       [-0.0005, -0.0697, -0.0194,  ...,  0.1304,  0.0334,  0.1321],
#                       [ 0.1154,  0.0340,  0.0516,  ..., -0.0304, -0.0019, -0.1093]])),
#              ('transformer_decoders.1.mlp_layer.layer.0.bias',
#               tensor([ 0.0080, -0.0930, -0.0669,  0.0273, -0.1080, -0.0776, -0.1210,  0.0226,
#                       -0.1118,  0.0567,  0.0554,  0.0298,  0.1079,  0.1112,  0.0304, -0.0878,
#                        0.0770,  0.0564,  0.0988,  0.0175, -0.0658,  0.0241, -0.0964, -0.0673,
#                        0.0606,  0.0894,  0.0726, -0.0799, -0.0584, -0.0238,  0.1174, -0.0995,
#                       -0.0441,  0.0631, -0.0872,  0.0180, -0.0145,  0.0852, -0.0675,  0.0341,
#                       -0.0463, -0.0175, -0.1239,  0.0361,  0.0687,  0.0779,  0.0410,  0.0753,
#                       -0.0129,  0.0084, -0.1193, -0.0406,  0.1061, -0.0490, -0.0767, -0.0766,
#                       -0.0440, -0.0231,  0.1169, -0.0996,  0.1161, -0.1197, -0.0666,  0.0593,
#                       -0.0716,  0.0774,  0.0308, -0.0831,  0.0430, -0.0602,  0.0496, -0.0574,
#                       -0.1239, -0.0173,  0.0326, -0.1136,  0.0876,  0.0263,  0.0790, -0.0598,
#                        0.0226, -0.0758,  0.0294, -0.0363, -0.0925,  0.0149, -0.0050,  0.0077,
#                       -0.0698,  0.0519,  0.1116, -0.0253,  0.0415, -0.1184,  0.0988,  0.0876,
#                        0.0533, -0.1224, -0.0125, -0.0566, -0.1268,  0.0310,  0.1028,  0.0976,
#                       -0.0179,  0.0601,  0.0963,  0.0021,  0.0348,  0.1187,  0.0318, -0.0612,
#                       -0.0690,  0.0661,  0.0156,  0.1229, -0.0121, -0.0560, -0.0185, -0.0977,
#                        0.0330,  0.1145, -0.1017,  0.0184,  0.0030, -0.0983,  0.0702,  0.0931])),
#              ('transformer_decoders.1.mlp_layer.layer.2.weight',
#               tensor([[ 0.0523,  0.0315, -0.0153,  ...,  0.0857, -0.0804, -0.0193],
#                       [ 0.0766,  0.0367,  0.0080,  ...,  0.0405, -0.0711,  0.0656],
#                       [ 0.0205, -0.0760,  0.0854,  ...,  0.0828, -0.0467,  0.0153],
#                       ...,
#                       [-0.0329,  0.0843, -0.0062,  ..., -0.0187,  0.0081,  0.0300],
#                       [ 0.0723, -0.0392, -0.0448,  ...,  0.0320,  0.0358,  0.0156],
#                       [-0.0810,  0.0552, -0.0188,  ...,  0.0809, -0.0671, -0.0568]])),
#              ('transformer_decoders.1.mlp_layer.layer.2.bias',
#               tensor([ 0.0615,  0.0489,  0.0688,  0.0220, -0.0158, -0.0342, -0.0665, -0.0395,
#                       -0.0039, -0.0012,  0.0176,  0.0158, -0.0156,  0.0769, -0.0319,  0.0686,
#                       -0.0376, -0.0069,  0.0219, -0.0214, -0.0682,  0.0348,  0.0174, -0.0784,
#                        0.0220, -0.0008, -0.0548,  0.0031,  0.0261,  0.0412,  0.0838,  0.0863,
#                       -0.0700, -0.0518,  0.0472,  0.0198, -0.0542,  0.0448,  0.0131,  0.0084,
#                       -0.0349,  0.0513,  0.0828,  0.0506, -0.0330, -0.0629, -0.0094, -0.0739,
#                       -0.0295,  0.0150,  0.0354, -0.0733,  0.0054,  0.0726,  0.0525,  0.0023,
#                        0.0759,  0.0364,  0.0754, -0.0160, -0.0814, -0.0552,  0.0503,  0.0509])),
#              ('transformer_decoders.1.layer_norm.weight',
#               tensor([0.9986, 0.9955, 0.9963, 1.0082, 1.0003, 0.9875, 0.9962, 1.0038, 0.9961,
#                       0.9956, 1.0010, 1.0045, 1.0039, 0.9996, 1.0062, 1.0041, 0.9962, 1.0025,
#                       1.0018, 1.0063, 0.9985, 1.0019, 0.9987, 0.9990, 1.0006, 1.0004, 1.0073,
#                       0.9984, 0.9983, 1.0012, 0.9999, 1.0027, 1.0062, 1.0047, 1.0055, 1.0000,
#                       0.9970, 1.0033, 0.9969, 1.0034, 1.0042, 1.0064, 1.0029, 1.0059, 1.0032,
#                       1.0014, 1.0063, 1.0008, 0.9979, 0.9969, 0.9985, 0.9972, 1.0015, 1.0044,
#                       1.0035, 0.9978, 0.9949, 1.0018, 1.0049, 1.0063, 0.9953, 1.0008, 1.0036,
#                       1.0054])),
#              ('transformer_decoders.1.layer_norm.bias',
#               tensor([-0.0027, -0.0036,  0.0004, -0.0048, -0.0025,  0.0008, -0.0030, -0.0017,
#                        0.0035,  0.0036,  0.0013, -0.0035,  0.0060,  0.0013,  0.0063, -0.0044,
#                        0.0009, -0.0029,  0.0005, -0.0035,  0.0041, -0.0019,  0.0028, -0.0011,
#                        0.0025,  0.0017,  0.0039,  0.0019, -0.0013, -0.0015, -0.0037,  0.0012,
#                        0.0001, -0.0029,  0.0037,  0.0042, -0.0030,  0.0030,  0.0023,  0.0030,
#                       -0.0034,  0.0019,  0.0019, -0.0033,  0.0029,  0.0004, -0.0054, -0.0027,
#                       -0.0007,  0.0002, -0.0017, -0.0018,  0.0028,  0.0021, -0.0025,  0.0004,
#                       -0.0027, -0.0032,  0.0056,  0.0075,  0.0041,  0.0006,  0.0002,  0.0052])),
#              ('transformer_decoders.2.attention_layer.Wq.weight',
#               tensor([[ 0.0953, -0.0908, -0.0349,  ...,  0.0840,  0.0612,  0.0779],
#                       [ 0.0785, -0.0772, -0.0351,  ...,  0.0687,  0.1000, -0.0672],
#                       [ 0.1215, -0.0672,  0.1103,  ...,  0.0436,  0.0220, -0.1136],
#                       ...,
#                       [-0.1133, -0.0830, -0.0431,  ...,  0.0758, -0.0908,  0.0075],
#                       [ 0.0920, -0.0037, -0.0304,  ...,  0.0481, -0.0582,  0.0162],
#                       [ 0.0721,  0.0500, -0.1080,  ..., -0.1161,  0.0317, -0.0876]])),
#              ('transformer_decoders.2.attention_layer.Wq.bias',
#               tensor([ 0.1104, -0.0371, -0.0682,  0.0528,  0.1154,  0.0584,  0.0681, -0.0414,
#                        0.0027, -0.0808, -0.0358,  0.0185,  0.0706, -0.0606,  0.0650,  0.0388,
#                       -0.0714, -0.0167, -0.0482,  0.0082, -0.0308,  0.0452, -0.0351, -0.0641,
#                        0.1191,  0.0514, -0.0891,  0.0318, -0.0457, -0.0315,  0.1016, -0.0103,
#                        0.0323,  0.0086,  0.0233,  0.0491, -0.1073,  0.0157,  0.1030,  0.0028,
#                       -0.0982,  0.0558, -0.0666, -0.1018, -0.0510, -0.0272,  0.0135, -0.0975,
#                        0.1015,  0.1207, -0.0430, -0.0792, -0.1164,  0.0172,  0.0444,  0.1204,
#                        0.0668,  0.0988, -0.0544, -0.0062,  0.0905,  0.0838,  0.1244, -0.1102,
#                       -0.0208, -0.0184, -0.1124, -0.0219, -0.0975,  0.0474,  0.1212, -0.0407,
#                       -0.0556,  0.0150, -0.0450, -0.0978,  0.0640, -0.1077, -0.0416, -0.0059,
#                        0.0865, -0.0177, -0.0036, -0.1106, -0.0625,  0.0220, -0.0077, -0.0965,
#                       -0.1049,  0.0889, -0.0138,  0.0598, -0.1156, -0.0387,  0.0133, -0.0090,
#                       [-0.0078, -0.0312, -0.1109,  ..., -0.0232, -0.0268,  0.0096],
#                       ...,
#                       [ 0.0249, -0.0151, -0.0374,  ...,  0.0879,  0.0331,  0.0680],
#                       [ 0.0382,  0.0516,  0.0295,  ...,  0.1048,  0.0595,  0.0687],
#                       [-0.1055, -0.0925, -0.0575,  ...,  0.0381, -0.0277, -0.1034]])),
#              ('transformer_decoders.2.attention_layer.Wv.bias',
#               tensor([-0.0952, -0.0798, -0.0286, -0.0104,  0.0850, -0.0365,  0.0201,  0.0462,
#                       -0.0074, -0.0142, -0.1064, -0.1220,  0.0785,  0.1203,  0.1265, -0.0215,
#                        0.0624, -0.0918,  0.0687, -0.1184,  0.0708,  0.0233,  0.0458, -0.0247,
#                       -0.1195,  0.1031,  0.0901,  0.0490,  0.0615,  0.0812, -0.0839,  0.1183,
#                       -0.0514,  0.0180,  0.0921, -0.0929, -0.1185,  0.0221, -0.0760,  0.0840,
#                       -0.0598,  0.0261, -0.0241, -0.0183,  0.0315,  0.0300, -0.0037, -0.0782,
#                       -0.0107, -0.1292,  0.0628,  0.0888,  0.0259,  0.0779,  0.0693, -0.1169,
#                        0.0141,  0.0426, -0.0801, -0.0111, -0.0680, -0.1184,  0.0736,  0.0833,
#                        0.0330,  0.0761,  0.1188,  0.1219, -0.0498, -0.0157, -0.0361, -0.1247,
#                        0.0085,  0.1011,  0.0926,  0.0408, -0.0962,  0.1137,  0.0093,  0.0177,
#                       -0.0286,  0.0406,  0.0888, -0.0441, -0.0772, -0.0920,  0.1266, -0.0951,
#                        0.0921, -0.0822, -0.0464,  0.0425,  0.0088,  0.1233,  0.0445, -0.1003,
#                        0.0341,  0.0617, -0.0467, -0.0529,  0.0770, -0.1061,  0.0607,  0.0362,
#                        0.0810,  0.1117, -0.1215, -0.0677, -0.0084,  0.0271, -0.0665, -0.0090,
#                       -0.0727, -0.0927, -0.0957, -0.0595, -0.0657,  0.0504,  0.1165,  0.0975,
#                       -0.0947, -0.1034,  0.0671, -0.0755,  0.0845, -0.0398,  0.0345,  0.1003])),
#              ('transformer_decoders.2.attention_layer.head_merge_layer.weight',
#               tensor([[-0.0141, -0.0548,  0.0609,  ...,  0.0146,  0.0363,  0.0274],
#                       [-0.0562,  0.0230, -0.0811,  ...,  0.0561, -0.0522,  0.0305],
#                       [ 0.0684,  0.0214,  0.0502,  ..., -0.0634, -0.0847, -0.0872],
#                       ...,
#                       [-0.0605, -0.0082,  0.0758,  ..., -0.0106, -0.0005,  0.0740],
#                       [ 0.0122,  0.0671, -0.0264,  ...,  0.0663,  0.0794,  0.0455],
#                       [ 0.0810, -0.0339,  0.0040,  ...,  0.0024, -0.0497, -0.0369]])),
#              ('transformer_decoders.2.attention_layer.head_merge_layer.bias',
#               tensor([ 0.0099,  0.0343, -0.0224,  0.0023,  0.0521, -0.0179,  0.0214,  0.0561,
#                        0.0794, -0.0525, -0.0630, -0.0748,  0.0365,  0.0745,  0.0193,  0.0124,
#                        0.0099,  0.0335,  0.0231, -0.0145,  0.0320, -0.0087,  0.0513,  0.0745,
#                       -0.0290,  0.0061,  0.0589, -0.0560, -0.0691,  0.0616,  0.0411,  0.0379,
#                       -0.0242, -0.0679, -0.0724,  0.0536, -0.0198,  0.0475, -0.0581, -0.0385,
#                       -0.0043, -0.0305,  0.0352,  0.0738,  0.0536,  0.0198,  0.0586,  0.0492,
#                        0.0749,  0.0462, -0.0354,  0.0162, -0.0268, -0.0303,  0.0149, -0.0525,
#                       -0.0389, -0.0656,  0.0376, -0.0492,  0.0113, -0.0715,  0.0480,  0.0185])),
#              ('transformer_decoders.2.mlp_layer.layer.0.weight',
#               tensor([[ 0.0809, -0.0866,  0.0363,  ..., -0.0398, -0.0370,  0.0489],
#                       [-0.0842, -0.0605,  0.0681,  ..., -0.0635, -0.0194,  0.0018],
#                       [ 0.0325,  0.1081, -0.0436,  ...,  0.1201,  0.0224,  0.0961],
#                       ...,
#                       [ 0.0309,  0.0426, -0.0283,  ..., -0.0773,  0.1207,  0.0426],
#                       [ 0.0707,  0.0806,  0.0180,  ...,  0.0550,  0.0839,  0.0308],
#                       [-0.0469, -0.1181,  0.1141,  ...,  0.0132, -0.0986, -0.0154]])),
#              ('transformer_decoders.2.mlp_layer.layer.0.bias',
#               tensor([-0.0393, -0.0576, -0.0266,  0.1112,  0.0007, -0.0972,  0.0744, -0.0376,
#                        0.0826,  0.0215,  0.0602,  0.0049, -0.0045, -0.1075,  0.1061, -0.0954,
#                        0.0522,  0.0422, -0.0805,  0.0860, -0.0996, -0.0447,  0.0576, -0.0578,
#                        0.0930,  0.0371, -0.0144, -0.1135, -0.0713,  0.0496,  0.0972,  0.1049,
#                        0.0019, -0.0016,  0.0822, -0.0183,  0.0541,  0.0728,  0.0788,  0.0789,
#                        0.0912,  0.0733,  0.0353,  0.0951,  0.0070,  0.0051, -0.0855, -0.1158,
#                        0.0588, -0.0794,  0.0553,  0.0513, -0.0385, -0.0782,  0.0891,  0.0709,
#                        0.0690,  0.0347, -0.0545,  0.0474,  0.0611, -0.0354, -0.0068, -0.0258,
#                        0.0596, -0.0938,  0.1121,  0.0649,  0.0879,  0.0942, -0.0160,  0.1056,
#                       -0.0108,  0.0950, -0.0779,  0.0598,  0.0442, -0.1222, -0.0543,  0.0061,
#                        0.0208,  0.0577,  0.0628,  0.0336, -0.0622, -0.0804,  0.0187,  0.0934,
#                       -0.1181, -0.1005, -0.0675, -0.0591, -0.0400, -0.0844, -0.0843, -0.0629,
#                       -0.0331, -0.0114, -0.1025, -0.1080,  0.0229, -0.0824,  0.0595, -0.1053,
#                        0.0283,  0.0475,  0.0938, -0.0391,  0.0814,  0.0667, -0.0630,  0.0515,
#                        0.0933,  0.0035, -0.0500, -0.1232, -0.0269, -0.0975,  0.1238, -0.1091,
#                       -0.0349, -0.0739,  0.0405, -0.0434, -0.0953,  0.0373, -0.0859,  0.0501])),
#              ('transformer_decoders.2.mlp_layer.layer.2.weight',
#                       [-0.0169, -0.0839,  0.0321,  ..., -0.0664,  0.0852,  0.0446],
#                       [-0.0030,  0.1147,  0.1099,  ..., -0.0667, -0.0371,  0.0720],
#                       ...,
#                       [-0.0006,  0.0277,  0.0293,  ..., -0.1159, -0.0922,  0.1035],
#                       [ 0.0842,  0.0646,  0.1063,  ..., -0.0439,  0.1010, -0.0300],
#                       [-0.0142,  0.1112,  0.1243,  ...,  0.0157, -0.0597, -0.0420]])),
#              ('transformer_decoders.3.attention_layer.Wk.bias',
#               tensor([ 0.0980,  0.1086, -0.1231,  0.0759, -0.1072,  0.1023,  0.0631,  0.0875,
#                        0.1063, -0.0130, -0.0482, -0.0571,  0.1152,  0.0327, -0.1009,  0.0606,
#                       -0.0649,  0.0518,  0.0294,  0.1066,  0.0251,  0.1152, -0.0415, -0.0204,
#                        0.0440,  0.0935,  0.0732, -0.0101, -0.1046, -0.1023,  0.0383,  0.0262,
#                        0.0263, -0.0170,  0.1094, -0.0362, -0.0593,  0.1118,  0.0363,  0.1075,
#                        0.0636,  0.1060, -0.0756,  0.0330,  0.0785,  0.0138,  0.0926, -0.0011,
#                       -0.0665, -0.0168, -0.0821, -0.0663,  0.1029, -0.0621, -0.0688, -0.0995,
#                       -0.0421, -0.0119,  0.0448,  0.0523,  0.0006, -0.1072,  0.0673, -0.0790,
#                       -0.0343, -0.0344,  0.0831,  0.0414, -0.0477,  0.1018, -0.0750, -0.0529,
#                        0.0782, -0.0045, -0.0079,  0.1197, -0.0113, -0.1167,  0.0254,  0.0716,
#                        0.0949, -0.0970, -0.0016, -0.1132,  0.0751, -0.0754, -0.0314, -0.0487,
#                        0.0605, -0.1005, -0.0219,  0.0018,  0.0477,  0.0052, -0.0705,  0.0364,
#                        0.0548,  0.0213,  0.1182, -0.0414, -0.0798, -0.0443, -0.1049, -0.0511,
#                        0.0980, -0.0108, -0.0994, -0.0028,  0.0620, -0.0207,  0.1073,  0.0980,
#                        0.0065,  0.1058, -0.1001, -0.0944,  0.1083,  0.0761,  0.0427,  0.1118,
#                        0.0004,  0.0137, -0.0552, -0.0734, -0.0471, -0.0134, -0.0400, -0.0215])),
#              ('transformer_decoders.3.attention_layer.Wv.weight',
#               tensor([[-0.0517, -0.0200,  0.0302,  ...,  0.1326,  0.0548,  0.0649],
#                       [ 0.0066, -0.1011, -0.1005,  ..., -0.0366, -0.0014,  0.0720],
#                       [ 0.0134,  0.0548, -0.1117,  ..., -0.0495,  0.0390,  0.1142],
#                       ...,
#                       [ 0.0842, -0.0536, -0.0826,  ...,  0.0091,  0.0542, -0.0386],
#                       [-0.0366, -0.0883,  0.0335,  ...,  0.0174,  0.0641, -0.0243],
#                       [-0.1057,  0.1142, -0.0411,  ...,  0.0859, -0.1157,  0.0691]])),
#              ('transformer_decoders.3.attention_layer.Wv.bias',
#               tensor([ 0.0419, -0.0833, -0.0465, -0.0195, -0.1017, -0.0026,  0.0288,  0.0835,
#                        0.0914, -0.1053,  0.0628, -0.1174, -0.1215, -0.1148, -0.0903,  0.1238,
#                        0.0242,  0.1197, -0.0140,  0.1027, -0.0968,  0.0685, -0.0628,  0.0638,
#                       -0.0538, -0.0261,  0.0918, -0.0443,  0.0781, -0.0202,  0.0277,  0.0977,
#                        0.1105, -0.0258, -0.1242,  0.0568, -0.0787,  0.0411,  0.0187,  0.0570,
#                        0.0358, -0.0425,  0.0489,  0.1152, -0.0324, -0.0473, -0.0875, -0.1045,
#                        0.0254, -0.0976, -0.0441, -0.0623, -0.0720, -0.1080,  0.0538, -0.0515,
#                        0.0798, -0.0381,  0.0640,  0.0521, -0.0936, -0.0688,  0.0009, -0.0788,
#                        0.1233, -0.1248,  0.0184,  0.0710, -0.1119, -0.0816, -0.0426, -0.0049,
#                       -0.0019,  0.0994, -0.0219,  0.0590, -0.0776, -0.1027, -0.0505, -0.1059,
#                        0.0917,  0.0389, -0.0293,  0.0746,  0.0850, -0.0287,  0.0689,  0.0256,
#                       -0.1160, -0.0778,  0.1114,  0.1251,  0.0714,  0.0567, -0.1110,  0.0464])),
#              ('transformer_decoders.9.attention_layer.Wk.weight',
#               tensor([[ 0.0337,  0.1071,  0.0390,  ..., -0.0974, -0.0910,  0.1228],
#                       [ 0.0483, -0.0371, -0.0350,  ...,  0.0133, -0.0890, -0.0414],
#                       [ 0.0963, -0.0657,  0.0856,  ..., -0.0230, -0.1005,  0.0189],
#                       ...,
#                       [ 0.0909, -0.0757,  0.0480,  ..., -0.0859, -0.0181, -0.0597],
#                       [-0.0627, -0.0620, -0.1047,  ..., -0.0117,  0.1057,  0.0195],
#                       [ 0.0159,  0.0408,  0.0961,  ...,  0.0117,  0.0890, -0.0055]])),
#              ('transformer_decoders.9.attention_layer.Wk.bias',
#               tensor([-0.0543, -0.0816,  0.1151,  0.0940, -0.0440, -0.0588,  0.0471, -0.0104,
#                       -0.0786, -0.0250,  0.0820, -0.0113, -0.0930, -0.1320, -0.0290, -0.0096,
#                       -0.0239,  0.0874,  0.0252, -0.0400, -0.0949,  0.0650,  0.1236,  0.0708,
#                       -0.0116, -0.0423, -0.1159, -0.1046,  0.0291, -0.0296, -0.0261, -0.0024,
#                       -0.0430, -0.0582,  0.0675, -0.0833,  0.0786, -0.0291,  0.1036, -0.1166,
#                       -0.0247, -0.0702, -0.1039, -0.0063,  0.0372, -0.0467, -0.0320,  0.0318,
#                        0.0930,  0.0395,  0.0121,  0.0172,  0.0308,  0.1298,  0.0951, -0.0522,
#                        0.0076, -0.1088, -0.0537,  0.0694,  0.0373, -0.0248,  0.0805, -0.0733,
#                        0.1038,  0.0671, -0.0351,  0.0577, -0.0440,  0.1255,  0.0273,  0.0669,
#                        0.0946, -0.0814, -0.0123,  0.0081,  0.0279,  0.0975, -0.0056, -0.0035,
#                        0.0577, -0.0751, -0.0544, -0.0839, -0.0984,  0.0538,  0.0025,  0.0275,
#                       -0.0629,  0.1054, -0.0601, -0.0925,  0.0647, -0.0636,  0.0053,  0.0305,
#                        0.0909, -0.0568,  0.0797, -0.0660, -0.0398,  0.0413,  0.0366,  0.0635,
#                        0.0631,  0.1001, -0.0880,  0.0208, -0.1023,  0.1096, -0.0217, -0.1153,
#                       -0.0311, -0.0369, -0.0617,  0.1015, -0.0617, -0.0412,  0.0601,  0.0626,
#                        0.0778, -0.1041,  0.0067, -0.0308,  0.0249, -0.1003, -0.1133,  0.1136])),
#              ('transformer_decoders.9.attention_layer.Wv.weight',
#               tensor([[ 0.0598, -0.0755,  0.0124,  ..., -0.0105, -0.1144,  0.0992],
#                       [ 0.0252, -0.1012, -0.0697,  ...,  0.0541, -0.0105, -0.0896],
#                       [ 0.0885, -0.0397,  0.0389,  ..., -0.0603, -0.1303,  0.0492],
#                       ...,
#                       [ 0.1018,  0.1030,  0.1000,  ..., -0.0307, -0.0431,  0.0525],
#                       [ 0.0432, -0.0583,  0.0423,  ...,  0.0264, -0.0295,  0.0330],
#                       [ 0.1092,  0.0318,  0.0815,  ...,  0.0250, -0.0102,  0.0741]])),
#              ('transformer_decoders.9.attention_layer.Wv.bias',
#               tensor([ 0.1061,  0.0697,  0.0654,  0.0305, -0.0178, -0.0523, -0.0636, -0.0074,
#                        0.0024,  0.0691,  0.0174,  0.0538,  0.0684,  0.0336, -0.0749,  0.1144,
#                        0.0958,  0.0118, -0.0235,  0.0411, -0.0842,  0.1222,  0.1207, -0.1099,
#                        0.0272,  0.0732, -0.0033,  0.0901,  0.0498,  0.0934, -0.0619, -0.0717,
#                       -0.1212,  0.0624,  0.0853, -0.0476, -0.1170, -0.1003, -0.0425, -0.0659,
#                       -0.0796,  0.1074, -0.0277, -0.0637,  0.0613, -0.0630, -0.0626, -0.0776,
#                        0.0562,  0.0209, -0.0405, -0.0825,  0.0870, -0.0120,  0.0950,  0.0315,
#                       -0.0890,  0.1225, -0.0789, -0.1171, -0.0366, -0.0334, -0.0036, -0.1154,
#                        0.0439, -0.0131,  0.0568,  0.0629, -0.1102,  0.0148,  0.0523,  0.0349,
#                        0.0227, -0.0833, -0.0759,  0.1137, -0.1125, -0.0395,  0.0121,  0.0555,
#                        0.0352, -0.0005,  0.0276, -0.0091,  0.0006,  0.1177,  0.0994,  0.0922,
#                       -0.0949,  0.0553,  0.1097,  0.0632,  0.0726, -0.1062, -0.1199,  0.0974,
#                        0.0455, -0.0731,  0.0606, -0.0159, -0.0706, -0.0949,  0.0176,  0.0851,
#                        0.0269,  0.0723, -0.1101, -0.0513,  0.0208,  0.0758, -0.0353, -0.1015,
#                        0.0913,  0.0401, -0.0424,  0.0217, -0.0795,  0.0703,  0.1147,  0.1052,
#                       -0.0675, -0.0405,  0.0499, -0.0287, -0.0193, -0.0892,  0.1094, -0.0397])),
#              ('transformer_decoders.9.attention_layer.head_merge_layer.weight',
#               tensor([[-2.0499e-02,  3.5230e-02, -2.8018e-02,  ..., -4.3252e-03,
#                        -4.9067e-02, -3.8576e-02],
#                       [ 4.4594e-02,  3.8125e-02, -2.8828e-03,  ..., -7.3332e-02,
#                         2.7931e-02,  6.5415e-02],
#                       [ 1.9032e-02, -3.8995e-03, -6.8655e-02,  ...,  1.1231e-02,
#                        -8.9663e-02,  3.5023e-02],
#                       ...,
#                       [ 6.7817e-02,  7.0970e-02, -5.2221e-03,  ...,  2.2048e-02,
#                        -5.0312e-02, -7.5600e-02],
#                       [-9.5255e-05,  3.4729e-02,  7.6929e-02,  ..., -8.8549e-02,
#                        -3.3426e-02, -4.1795e-02],
#                       [-3.5839e-02,  1.6976e-02,  3.5181e-02,  ..., -2.6986e-02,
#                         8.4256e-02,  7.5097e-02]])),
#              ('transformer_decoders.9.attention_layer.head_merge_layer.bias',
#               tensor([ 0.0658,  0.0562, -0.0229,  0.0258,  0.0583, -0.0001, -0.0050, -0.0161,
#                        0.0440, -0.0810, -0.0828, -0.0326, -0.0044,  0.0370, -0.0690, -0.0585,
#                        0.0795,  0.0812, -0.0028,  0.0183,  0.0573,  0.0486, -0.0882,  0.0600,
#                        0.0341, -0.0214, -0.0156, -0.0698,  0.0448, -0.0517,  0.0249, -0.0406,
#                       -0.0158,  0.0148,  0.0078,  0.0795,  0.0369,  0.0207,  0.0671,  0.0241,
#                       -0.0381,  0.0335,  0.0411, -0.0502,  0.0461, -0.0013, -0.0390, -0.0640,
#                       -0.0115,  0.0182,  0.0703, -0.0600, -0.0656,  0.0364, -0.0147, -0.0387,
#                       -0.0255,  0.0583, -0.0747,  0.0229,  0.0778, -0.0532,  0.0304,  0.0055])),
#              ('transformer_decoders.9.mlp_layer.layer.0.weight',
#               tensor([[-0.1031, -0.0096,  0.0100,  ...,  0.1294,  0.0410, -0.1156],
#                       [ 0.0734,  0.0059,  0.0915,  ...,  0.1084,  0.0288,  0.1026],
#                       [ 0.0426, -0.0997, -0.0383,  ..., -0.1004,  0.0283, -0.0915],
#                       ...,
#                       [-0.0296,  0.0152, -0.1348,  ..., -0.0369,  0.0412,  0.1130],
#                       [ 0.0438,  0.1179, -0.0676,  ...,  0.0489,  0.0153, -0.0044],
#                       [ 0.0593, -0.0445,  0.0574,  ...,  0.0626,  0.0780,  0.0575]])),
#              ('transformer_decoders.9.mlp_layer.layer.0.bias',
#               tensor([ 0.0417, -0.0502,  0.0240, -0.0066,  0.0553, -0.0438,  0.1137,  0.0182,
#                        0.0568,  0.0719,  0.0347,  0.0645, -0.1027,  0.0409, -0.0410,  0.0981,
#                        0.0885,  0.0226, -0.0737, -0.0648,  0.0290,  0.0463, -0.0686,  0.0525,
#                        0.0219, -0.0307,  0.0674,  0.0923,  0.0111, -0.0433, -0.0978,  0.0907,
#                        0.0956,  0.0412,  0.0735, -0.0664,  0.0636,  0.0933,  0.0955, -0.0686,
#                        0.0157,  0.0614, -0.0882,  0.0080, -0.0842, -0.0866, -0.0894, -0.0854,
#                       -0.0753,  0.0621, -0.0315, -0.0427, -0.0574,  0.0254,  0.0120, -0.0905,
#                        0.0558,  0.1109, -0.0169, -0.0978, -0.1146, -0.0551,  0.0637, -0.0921,
#                       -0.0286,  0.0573,  0.1121,  0.0588, -0.0309, -0.0719, -0.0807, -0.0643,
#                       -0.0459, -0.0291,  0.0526,  0.0473, -0.0337,  0.0454,  0.0923,  0.0887,
#                       -0.0669,  0.0458,  0.1084,  0.0552, -0.0681, -0.0206,  0.0074, -0.0535,
#                        0.1214,  0.0142,  0.1094,  0.1106, -0.0172,  0.0292, -0.0024, -0.0468,
#                        0.0157,  0.0634,  0.1106,  0.0238, -0.1175, -0.0430,  0.0113,  0.0041,
#                        0.0678, -0.0497, -0.0948, -0.0748, -0.0358,  0.0996, -0.0023,  0.1123,
#                       -0.0948,  0.0187, -0.0267, -0.0080, -0.0406,  0.1192,  0.1263,  0.0191,
#                        0.0593,  0.0054, -0.0296,  0.0884, -0.1097, -0.0186,  0.0360,  0.0026])),
#              ('transformer_decoders.9.mlp_layer.layer.2.weight',
#               tensor([[-0.0098,  0.0305,  0.0564,  ..., -0.0748,  0.0817, -0.0317],
#                       [ 0.0036, -0.0252, -0.0042,  ..., -0.0376,  0.0591,  0.0131],
#                       [-0.0976,  0.0821, -0.0209,  ...,  0.0316, -0.0421,  0.0193],
#                       ...,
#                       [ 0.0060,  0.0101, -0.0555,  ...,  0.0272, -0.0242,  0.0571],
#                       [ 0.0147,  0.0265,  0.0524,  ..., -0.0816,  0.0147, -0.0821],
#                       [ 0.0757, -0.0456, -0.0627,  ...,  0.0431, -0.0801,  0.0840]])),
#              ('transformer_decoders.9.mlp_layer.layer.2.bias',
#               tensor([-0.0342,  0.0287,  0.0636,  0.0215, -0.0177,  0.0310, -0.0101,  0.0234,
#                       -0.0453,  0.0279,  0.0034, -0.0466,  0.0307,  0.0083, -0.0768,  0.0791,
#                       -0.0276, -0.0349,  0.0254,  0.0471,  0.0432,  0.0725,  0.0334, -0.0745,
#                        0.0525, -0.0208, -0.0143, -0.0760, -0.0449, -0.0835, -0.0400,  0.0314,
#                       -0.0325, -0.0188, -0.0260,  0.0465,  0.0242,  0.0055,  0.0407,  0.0159,
#                       -0.0574,  0.0331,  0.0167,  0.0676,  0.0823,  0.0385, -0.0565, -0.0506,
#                        0.0482,  0.0588, -0.0015,  0.0119, -0.0240, -0.0517, -0.0170,  0.0680,
#                        0.0047,  0.0542,  0.0059,  0.0042, -0.0888, -0.0905, -0.0491, -0.0765])),
#              ('transformer_decoders.9.layer_norm.weight',
#               tensor([1.0054, 1.0219, 1.0124, 1.0194, 1.0279, 1.0371, 1.0127, 1.0173, 1.0053,
#                       1.0103, 1.0222, 1.0082, 1.0254, 1.0002, 1.0130, 1.0165, 1.0138, 1.0100,
#                       1.0187, 1.0147, 1.0326, 1.0030, 1.0075, 1.0073, 1.0165, 1.0120, 1.0198,
#                       1.0018, 1.0154, 1.0136, 1.0126, 1.0071, 1.0330, 1.0202, 1.0132, 1.0162,
#                       1.0091, 1.0262, 1.0112, 1.0339, 1.0050, 1.0235, 1.0195, 1.0150, 1.0118,
